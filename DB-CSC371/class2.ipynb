-- %% [markdown]
-- # Class 2

-- %% [markdown]
-- ## Create Database

-- %%
CREATE DATABASE db_mydatabase;

-- %% [markdown]
-- ## Create Table

-- %%
-- make sure you have selected correct db before executing this command
-- or use 'USE db_mydatabase;' command to execute command in specific database
CREATE TABLE tbl(
    id INT NOT NULL,
    name VARCHAR(20) NULL
);

-- %% [markdown]
-- ## Insert Data in Table

-- %%
INSERT INTO tbl VALUES(345, 'ALI');

-- %% [markdown]
-- ## Display data from Table

-- %%
-- show all fields from table
SELECT * FROM tbl;

-- %%
-- show all id fields from tb1
SELECT id FROM tbl;

-- %% [markdown]
-- ## Alter Table and make 'id' Primary Key

-- %%
-- ALTER TABLE [TableName] ADD CONSTRAINT [name_of_PrimaryKey] PRIMARY KEY(column(s) name);
ALTER TABLE tbl ADD CONSTRAINT pk_id PRIMARY KEY(id);

-- %% [markdown]
-- ## Delete all data from Table

-- %%
TRUNCATE TABLE tbl;

-- %% [markdown]
-- ## Delete Table

-- %%
DROP TABLE tbl;

-- %% [markdown]
-- ## Delete Database

-- %%
-- before dropping database make sure it is not in use
DROP DATABASE db_mydatabase;

-- %% [markdown]
-- ## Rename Database

-- %%
sp_renamedb 'db_mydatabase', 'new_database';

-- %% [markdown]
-- ## Rename Table

-- %%
-- sp_rename 'dbo.oldTableName', 'newTableName';
sp_rename 'dbo.tbl', 'myTable';

-- %% [markdown]
-- ## Rename Column

-- %%
-- sp_rename 'tbl.oldColumn', 'newColumnName';
sp_rename 'myTable.name', 'first_name';
